# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Smartfon.xlsx')

# %%
all_shf_os = pd.read_excel('123.xlsx')

# %%
df = df.merge(all_shf_os, left_on='Unnamed: 0', right_on='Инвентарный')

# %%
df.head(1)
# Out:
#   Unnamed: 0                                       Наименование  \
# 0  DD-005816  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
#
#   Заводской (Серийный) номер            IMEI1      ANYDESK  \
# 0                R9PR6044BXN  356525688272596  471660879.0
#
#                   Почта  Алтел or Beeline                           ФИО_x  \
# 0  dd005816sf@gmail.com      7.006659e+09  Избаева Сабира Рахманбердиевна
#
#           Отделение_x Теле2  Unnamed: 10 Инвентарный  \
# 0  Отделение Сарыагаш   NaN          NaN   DD-005816
#
#                                                   ОС  \
# 0  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
#
#                             ФИО_y         Отделение_y
# 0  Избаева Сабира Рахманбердиевна  Отделение Сарыагаш

# %%
df.to_excel('Smartfon1.xlsx',index=False)

# %%
#axis1 = pd.concat([df['Unnamed: 0'],all_shf_os['Инвентарный']],axis=1)

# %%
# Out:
#     Unnamed: 0                                       Наименование  \
# 0    DD-005816  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 1    DD-005817  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 2    DD-005818  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 3    DD-005819  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 4    DD-005820  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# ..         ...                                                ...
# 182  DD-006061  Смартфон Samsung Galaxy А03s, Black (SM-A037F/DS)
# 183  DD-006057  Смартфон Samsung Galaxy А03s, Black (SM-A037F/DS)
# 184  DD-006060  Смартфон Samsung Galaxy А03s, Black (SM-A037F/DS)
# 185  DD-006062  Смартфон Samsung Galaxy А03s, Black (SM-A037F/DS)
# 186  DD-006056  Смартфон Samsung Galaxy А03s, Black (SM-A037F/DS)
#
#     Заводской (Серийный) номер            IMEI1      ANYDESK  \
# 0                  R9PR6044BXN  356525688272596  471660879.0
# ...

# %%
axis1
# Out:
#      Unnamed: 0                                       Наименование  \
# 0     DD-005816  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 1     DD-005817  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 2     DD-005818  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 3     DD-005819  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 4     DD-005820  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# ...         ...                                                ...
# 5649        NaN                                                NaN
# 5650        NaN                                                NaN
# 5651        NaN                                                NaN
# 5652        NaN                                                NaN
# 5653        NaN                                                NaN
#
#      Заводской (Серийный) номер            IMEI1      ANYDESK  \
# 0                   R9PR6044BXN  356525688272596  471660879.0
# ...
