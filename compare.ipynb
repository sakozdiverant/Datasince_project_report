# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 680.8 kB/s eta 0:00:001m530.7 kB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel('/media/D/musor/jp/552.xlsx')

# %%
df2 = pd.read_excel('/media/D/musor/jp/Smartfon.xlsx')

# %%
df.head(2)
# Out:
#   Инвентарный                                 ОС  \
# 0   DD-002426                   AFC 04 Картотека
# 1   DD-001793  IP- телефон D-LINK DPH-150SE/E/F1
#
#                               ФИО       Отделение
# 0  Еламанов Арман Рахманбердиевич  Отделение Абай
# 1  Еламанов Арман Рахманбердиевич  Отделение Абай

# %%
df2.head(2)
# Out:
#   Инвентарный                                       Наименование  \
# 0   DD-005816  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 1   DD-005817  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
#
#   Заводской (Серийный) номер         IMEI1      ANYDESK                 Почта  \
# 0                R9PR6044BXN  3.565257e+14  471660879.0  dd005816sf@gmail.com
# 1                R9PR6044JED  3.565257e+14  389412395.0  dd005817sf@gmail.com
#
#    Алтел or Beeline                             ФИО           Отделение  \
# 0      7.006659e+09  Избаева Сабира Рахманбердиевна  Отделение Сарыагаш
# 1      7.717795e+09           Қалау Ерасыл Қанатұлы    Отделение Алмалы
#
#   Unnamed: 9  Unnamed: 10
# 0      Алтел          NaN
# 1    Beeline          NaN

# %%
merged_df = pd.merge(df2, df[['Инвентарный', 'ФИО', 'Отделение']], how='left', left_on='Инвентарный', right_on='Инвентарный')

# %%
merged_df.head(10)
# Out:
#   Инвентарный                                       Наименование  \
# 0   DD-005816  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 1   DD-005817  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 2   DD-005818  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 3   DD-005819  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 4   DD-005820  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 5   DD-005821  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 6   DD-005822  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 7   DD-005823  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 8   DD-005824  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
# 9   DD-005825  Смартфон Samsung Galaxy А02s, Black (SM-A025FZ...
#
#   Заводской (Серийный) номер         IMEI1      ANYDESK                 Почта  \
# 0                R9PR6044BXN  3.565257e+14  471660879.0  dd005816sf@gmail.com
# 1                R9PR6044JED  3.565257e+14  389412395.0  dd005817sf@gmail.com
# ...

# %%
merged_df.to_excel('/media/D/musor/jp/new1.xlsx', index=False)
